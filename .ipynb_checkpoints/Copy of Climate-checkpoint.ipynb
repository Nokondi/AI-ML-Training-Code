# %%
import requests
from datetime import date, datetime, timedelta
from dateutil.relativedelta import relativedelta
import pandas as pd

# URL for county FIPS codes
fips = "https://www2.census.gov/geo/docs/reference/codes/files/national_county.txt"

# URL for NOAA datasets
noaa = "https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid="

# NOAA dataset access token
h = {"token": "cBzKIKbjojRJUnLZNjEQtbXVeXZEPkyR"}

# NOAA dataset id
id = "GHCND"

startdate = datetime(1970, 1, 1, 0, 0, 0)
enddate = startdate + timedelta(days=1)

fips_data = requests.get(fips)
fips_data = fips_data.content.decode('UTF-8').split('\r\n')

for i in range(0, len(fips_data)):
  row = fips_data[i].split(',')
  fips_data[i] = row
print(fips_data[0])

for i in range(0, len(fips_data)):
  climate_data_json = requests.get(noaa + id + "&limit=1000" + "&locationid=FIPS:"+ fips_data[i][1] + fips_data[i][2] + "&startdate=" + str(startdate.isoformat()) + "&enddate=" + str(enddate.isoformat()), headers=h)
  print(climate_data_json.content)
# Out:
# ['AL', '01', '001', 'Autauga County', 'H1']
# ...
